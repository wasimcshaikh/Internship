# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimcshaikh/Internship/blob/main/Task_2/Bar_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#barchart using dataset ign_scores
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/ign_scores.csv")
x=df['Platform']
y=df['Action']
z=plt.bar(x,y,color='green')
plt.show()

# %%
#barchart using dataset insurance
import pandas as pd
import matplotlib.pyplot as plt
mk=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/insurance.csv")
x=mk['age']
y=mk['sex']
mkp=plt.bar(x,y,color='black')

# %%
#simple bar chart display using dataset tips
import plotly.express as px 
df=px.data.tips()
fig=px.bar(df,x='day',y='time')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#simple bar chart using data set iris
import plotly.express as px
df=px.data.iris()
fig=px.bar(df,x="sepal_width",y="sepal_length",color="species")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
