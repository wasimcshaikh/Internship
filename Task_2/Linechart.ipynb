# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimcshaikh/Internship/blob/main/Task_2/Linechart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/flight_delays.csv")
x=df['Month']
y=df['AA']
plt.plot(x,y,'r')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/fifa.csv")
x=df['Date']
y=df['ARG']
plt.plot(x,y,'g')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/ign_scores.csv")
x=df['Platform']
y=df['Action']
plt.plot(x,y,"--y")
