# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimcshaikh/Internship/blob/main/Task_2/Scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#scatter plot using dataset spotify
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/spotify.csv")
plt.scatter(df.Date,df.Despacito,color="green")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/fifa.csv")
plt.scatter(df.Date,df.ARG,color='r')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Internship/Datasets/candy.csv")
plt.scatter(df.competitorname,df.chocolate)
